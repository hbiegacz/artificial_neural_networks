# %%
import pandas as pd
import numpy as np

# %%
def rmsle(y_true,y_pred):
    n = len(y_true)
    msle = np.mean([(np.log(max(y_pred[i],0) + 1) - np.log(y_true[i] + 1)) ** 2.0 for i in range(n)])
    return np.sqrt(msle)

# %%
targets = pd.read_csv("data.csv")
targets.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
preds = np.random.rand(len(targets))*100

# %%
pd.DataFrame(preds).to_csv("muchomorki.csv", index=False, header=None)

# %%
preds = pd.read_csv("muchomorki.csv",header=None)

# %%
rmsle(targets.values,preds.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 rmsle(targets.values,preds.values)
#
# Cell In[23], line 3, in rmsle(y_true, y_pred)
#       1 def rmsle(y_true,y_pred):
#       2     n = len(y_true)
# ----> 3     msle = np.mean([(np.log(max(y_pred[i],0) + 1) - np.log(y_true[i] + 1)) ** 2.0 for i in range(n)])
#       4     return np.sqrt(msle)
#
# TypeError: can only concatenate str (not "int") to str
